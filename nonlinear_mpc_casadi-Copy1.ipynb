# %% [markdown]
# ## Nonlinear MPC with Kinematic Bicycle Model
#
# The bicycle model is the same one used in <a href=https://link-springer-com.stanford.idm.oclc.org/article/10.1007/s13177-020-00226-1#Tab4>this paper (Figure 3)</a>
#
# The model has state and input:
# \begin{gather*}
# z = \begin{bmatrix}x\\ y\\ v\\ \psi\end{bmatrix},\quad
# u = \begin{bmatrix}a\\ \delta_f\end{bmatrix},\quad
# \end{gather*}
#
# The 4 states are:
# * $x$ and $y$, the car's position in the world frame
# * $v$, the car's velocity
# * $\psi$, the angle of the car's centerline in the world frame
#
#
# The two control signals are $a$, the acceleration command, and $\delta_f$, the front steering angle (in radians).
#
# $\beta$ is the angle between the car's centerline and its velocity vector. It is not really a state, but a function of $\delta_f$.
#
# The nonlinear model is:
# \begin{gather*}
# \begin{bmatrix}
# \dot x\\ \dot y\\ \dot v\\ \dot\psi
# %\\ \dot\beta
# \end{bmatrix} =
# \begin{bmatrix}
# v\cos(\psi + \beta)
# \\
# v\sin(\psi + \beta)
# \\
# a
# \\
# \frac{v}{l_r}\sin(\beta)
# %\\
# %\frac{v}{l_f + l_r}\tan(\delta_f) - \frac{v}{l_r}\sin(\beta)
# \end{bmatrix}, \quad \beta = \tan^{-1}\Big(\frac{l_r}{l_r + l_f}\tan(\delta_f)\Big)
# \end{gather*}

# %% [markdown]
# ## Casadi setup
# From http://casadi.sourceforge.net/v3.4.4/users_guide/casadi-users_guide.pdf

# %%
# Library dependencies
import casadi
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib        as mpl
import bezier

# Local dependencies
from direct_collocation  import MpcProblem
from KinematicBicycleCar import KinematicBicycleCar
from roadrunner_2        import Roadrunner, Segment
from complex_track_2     import complex_track_2 as test_road

# %% [markdown]
# ## Initialize the car and road model

# %%
# Initialize the car model with 0.05 second steps and 30 step lookahead
car = KinematicBicycleCar(N=30, step=0.075)

DESIRED_SPEED = 10.0

# %%
# %matplotlib notebook

n_test_road_pts,_ = np.shape(test_road)

roadrunner = Roadrunner(road_center = test_road,                    # Road centerline points
                        road_width  = np.ones(n_test_road_pts)*5.0, # constant lane width of 5 meters
                        P           = 10, # Number of points to try curve-fitting at a time
                        start_pct = 0.3, end_pct = 0.7)

# %%
ax = roadrunner.plot()
i = 0

while i < n_test_road_pts-roadrunner.P:
    
    end_idx   = int(roadrunner.P*roadrunner.end_pct)
    start_idx = int(roadrunner.P*roadrunner.start_pct)

    seg = roadrunner.segments[i//(end_idx - start_idx)]
                              
    start_xy = roadrunner.to_body_frame(np.reshape(roadrunner.road_center[i+start_idx],(1,2)), seg.transform_angle, seg.transform_offset)
    end_xy   = roadrunner.to_body_frame(np.reshape(roadrunner.road_center[i+end_idx],  (1,2)),   seg.transform_angle, seg.transform_offset)
    
    start_tmp = Roadrunner.to_world_frame(np.reshape(start_xy,(1,2)), seg.transform_angle, seg.transform_offset)
    end_tmp = Roadrunner.to_world_frame(np.reshape(end_xy,(1,2)), seg.transform_angle, seg.transform_offset)
    
    ax.scatter(start_tmp[0,0], start_tmp[0,1], color="blue",s=20)
    ax.scatter(end_tmp[0,0], end_tmp[0,1], color="navy",s=40)
    
    start_pct,_ = Roadrunner.find_closest_pt(seg.curve, np.reshape(start_xy,(2,1)), start=0.25, end=0.35)
    end_pct,_   = Roadrunner.find_closest_pt(seg.curve, np.reshape(end_xy,  (2,1)), start=0.65, end=0.75)
    #print("start, end", start_pct, end_pct)
    start_xy = Roadrunner.to_world_frame(np.reshape(seg.curve.evaluate(start_pct),(1,2)), seg.transform_angle, seg.transform_offset)
    end_xy = Roadrunner.to_world_frame(np.reshape(seg.curve.evaluate(end_pct),(1,2)), seg.transform_angle, seg.transform_offset)
    
    ax.scatter(start_xy[0,0], start_xy[0,1], color="red",s=10)
    ax.scatter(end_xy[0,0], end_xy[0,1], color="orange", s=10)
    
    i += (end_idx - start_idx)
# Out:
# <img src="data:image/png;base64,..." width="640">
# find_closest_pt may be unreliable: closest match found for [[77.16713804]
#  [ 7.88931379]] is [2.93562932] away at s = 0.758203125, B(s) = [[74.23589654]
#  [ 8.04975936]]
# find_closest_pt may be unreliable: closest match found for [[66.18734851]
#  [11.74389692]] is [3.12229226] away at s = 0.758203125, B(s) = [[63.07753236]
#  [11.46505569]]
# find_closest_pt may be unreliable: closest match found for [[61.84433384]
#  [ 5.5287385 ]] is [2.59258443] away at s = 0.758203125, B(s) = [[59.29453309]
#  [ 5.05968609]]

# %% [markdown]
# ## Boundary functions
# We represent the road boundaries as a series of polygons. At each step $x_k$, $x_{k+1},...,x_N$, the car's x-y position is bounded by a 4-sided polygon.
# The polygons for successive states overlap, allowing the car to steer and slow down / speed up within the confines of the road.
#
# This image shows 5 successive bounds from $k$ to $k+5$. The $k+5^{th}$ bound is in red.
# ![title](polygon_bounds.png)

# %%
# terrible hack, need to fix right away

global dist_already_traveled
dist_already_traveled = 0.0

def road_center(model:KinematicBicycleCar, k:int)->np.array:
    global dist_already_traveled

    #(xy, angle, _) = roadrunner.evaluate(model.step*np.sum(model.state_estimate[2,:k]), full_data=True)
    (xy, angle, _) = roadrunner.evaluate(model.step*DESIRED_SPEED*k, full_data=True)

    center = np.empty((3,))
    center[0:2] = np.reshape(xy, 2)
    center[2]   = angle
    return center

# Test

def bound_x(model:KinematicBicycleCar, k:int)->[np.array]:
    # Returns a 4-sided polygon bound, like this:
    # x2-------x3
    #   \  o  /
    #  x1-----x4
    # successive bounds will overlap each other
    # so there is freedom to slow down or speed up the vehicle.
    
    dist_behind = (k-5)*model.step*DESIRED_SPEED # 5 steps behind * timestep * velocity at point k
    #dist_behind = np.sum(model.state_estimate[2,k-5:k])*model.step
    #print("Looking behind by", dist_behind)
    (center_minus, angle_minus, width_minus) = roadrunner.evaluate(dist_behind, full_data=True)
    
    dist_ahead = (k+5)*model.step*DESIRED_SPEED # 5 steps ahead * timestep * velocity at point k
    #dist_ahead = np.sum(model.state_estimate[2,k:k+5])*model.step
    #print("Looking ahead by", dist_ahead)
    (center_plus, angle_plus, width_plus) = roadrunner.evaluate(dist_ahead, full_data=True)

    center_minus = np.reshape(center_minus,(2,))
    center_plus = np.reshape(center_plus,(2,))
    
    #print("Got center points", center_minus, center_plus)
    #print("center angles:", 180.0/np.pi*(angle_minus), 180.0/np.pi*(angle_plus))
    # These four points define the 2d bounding box for the car at state xk
    
    p1 = np.reshape(np.array([center_minus[0] + width_minus/2.0*np.cos(angle_minus-np.pi/2),
                   center_minus[1] + width_minus/2.0*np.sin(angle_minus-np.pi/2)]), (2,))
    
    p2 = np.reshape(np.array([center_minus[0] + width_minus/2.0*np.cos(angle_minus+np.pi/2),
                   center_minus[1] + width_minus/2.0*np.sin(angle_minus+np.pi/2)]), (2,))
    
    p3 = np.reshape(np.array([center_plus[0] + width_plus/2.0*np.cos(angle_plus+np.pi/2),
                   center_plus[1] + width_plus/2.0*np.sin(angle_plus+np.pi/2)]), (2,))
    
    p4 = np.reshape(np.array([center_plus[0] + width_plus/2.0*np.cos(angle_plus-np.pi/2),
                   center_plus[1] + width_plus/2.0*np.sin(angle_plus-np.pi/2)]), (2,))
    
    # The slopes between the points
    slope12 = (p2[1]-p1[1])/(p2[0]-p1[0]); slope12 = 1e4 if np.isnan(slope12) else slope12
    slope23 = (p3[1]-p2[1])/(p3[0]-p2[0]); slope23 = 1e4 if np.isnan(slope23) else slope23
    slope43 = (p3[1]-p4[1])/(p3[0]-p4[0]); slope43 = 1e4 if np.isnan(slope43) else slope43
    slope14 = (p1[1]-p4[1])/(p1[0]-p4[0]); slope14 = 1e4 if np.isnan(slope14) else slope14

    # form 4 linear inequalities to represent the box
    # we either have 0.0 >= ax + by + c >= -Inf
    # or             Inf >= ax + by + c >= 0.0
    
    # since y = (x-x0)*slope + y0
    # use the line 0 = x*slope - y + y0 - x0*slope as the upper / lower bound
    
    #            (upper)
    #     p2-----slope23------p3
    #    /                    /
    # slope12 (upper)   slope34 (lower)
    #  /                   /
    # p1-----slope14-----p4
    #        (lower)
    
    # upper bounds (if slope is positive)
    bounds = [
        np.array([np.inf, slope12, -1.0, (p1[1]-p1[0]*slope12), 0.0]),
        np.array([np.inf, slope23, -1.0, (p2[1]-p2[0]*slope23), 0.0]),
    
    # lower bounds (if slope is positive)
        np.array([0.0, slope43, -1.0, (p4[1]-p4[0]*slope43), -np.inf]),
        np.array([0.0, slope14, -1.0, (p1[1]-p1[0]*slope14), -np.inf]),
    ]
    
    for i in range(len(bounds)): # Handle the negative-slope flipped cases
    
        if np.sign(bounds[i][1]) == -1: # slope is negative, so inequality flips
            bounds[i][0], bounds[i][4] = -bounds[i][4], -bounds[i][0]
            
    return bounds, np.vstack([p1,p2,p3,p4])

# %% [markdown]
# ## Run the MPC algorithm

# %%
roadrunner.reset()
# start a bit ahead of the first point to have space for looking back on the road
roadrunner.advance(car.step*400*DESIRED_SPEED)

xy = np.reshape(roadrunner.evaluate(),(2,))
ic = [xy[0], xy[1], DESIRED_SPEED, float(roadrunner.get_angle())]
car.set_initial(ic)
print("Starting at initial conditions", ic)

# This is the model:
# https://link-springer-com.stanford.idm.oclc.org/article/10.1007/s13177-020-00226-1/figures/3
mpcprob = MpcProblem(car,     # casadi.DaeBuilder()
                     bound_x=bound_x,
                     road_center=road_center,
                    )
# Out:
# Starting at initial conditions [80.12741238733891, 2.116275288822248, 10.0, 1.3693496213688705]

# %%
# %matplotlib notebook

# Controls the NUMBER of iterations to run the MPC algorithm.
n_runs = 350 # 350 will cover the whole double-lane-change test

x_plan = np.empty((mpcprob.model.n,n_runs+1)) # store the steps that get executed (n_runs)
u_plan = np.empty((mpcprob.model.m,n_runs))   # store the control inputs that get executed
x_true = np.empty((mpcprob.model.n,n_runs+1)) # store the state as simulated for each control input by an integrator
x_true[:,0] = ic # initial conditions
x_plan[:,0] = ic
# store the polygon boundary for each step, so we can plot them later
polygon_boundaries = np.zeros((n_runs+mpcprob.model.N,4,2))

fig_traj = plt.figure(figsize=(12,4))
ax_traj = fig_traj.add_subplot(111)

plt.ion()
fig_traj.show()

states = ax_traj.plot(x_true[0,0], x_true[1,0], color="red")[0]
#ax_traj.quiver(x_true[0,0], x_true[1,0], x_true[2,0]*np.cos(x_true[3,0]), x_true[2,0]*np.sin(x_true[3,0]), color="blue")

pts_new = np.empty((n_runs,3))
pts_old = np.empty((n_runs,3))

fig_traj.canvas.draw()


for k in range(n_runs):
    # Solve the MPC problem
    xk_opt, uk_opt, sol = mpcprob.run(x_true[:,k])
    
    # Save the next state x_k+1 and control u_k+1
    for i in range(mpcprob.model.n):
        x_plan[i,k+1] = xk_opt[i][1]
    for i in range(mpcprob.model.m):
        u_plan[i,k] = uk_opt[i][1]
    x_true[:,k+1] = mpcprob.simulate(x_true[:,k], u_plan[:,k])
    
    # Compute distance traveled (approximately)
    step_xy = np.linalg.norm(x_true[:,k+1]-x_true[:,k], 2)
    
    # Save the 4 points that represent the polygon boundary at state k
    bounds,p = bound_x(mpcprob.model,0)
    polygon_boundaries[k,:,:] = p
    
    # Messing with the roadrunner advance
    seg = roadrunner.segments[roadrunner._segment_ptr]
    pt = np.asfortranarray(roadrunner.to_body_frame(np.reshape(x_true[0:2,k+1],(1,2)), seg.transform_angle, seg.transform_offset))
    
    (s_new,_) = roadrunner.find_closest_pt(seg.curve,
                                        np.reshape(pt,(2,1)),
                                          start=roadrunner.current_pct,
                                          end=roadrunner.current_pct + 0.1)
    delta_s = s_new - roadrunner.current_pct
    
    pts_new[k,0:2] = roadrunner.evaluate(delta_s*roadrunner.segments[roadrunner._segment_ptr].curve.length)
    
    #roadrunner.advance(step_xy*(1))
    # hack hack hack
    if roadrunner.current_pct + delta_s > seg.end_pct:
        delta_xy = (seg.end_pct - roadrunner.current_pct)*seg.curve.length + \
                   (delta_s - (seg.end_pct - roadrunner.current_pct))*roadrunner.segments[roadrunner._segment_ptr+1].curve.length
    else:
        delta_xy = delta_s*seg.curve.length
    roadrunner.advance(delta_xy) # doesn't work??
    pts_new[k,2] = delta_xy
    pts_old[k,0:2] = roadrunner.evaluate()
    pts_old[k,2] = step_xy
    
    
    # Plot arrows and x-y states
    ax_traj.clear()
    #ax_traj.quiver(x_true[0,:k], x_true[1,:k], x_true[2,:k]*np.cos(x_true[3,:k]), x_true[2,:k]*np.sin(x_true[3,:k]), color="blue")
    ax_traj.scatter(x_true[0,:k], x_true[1,:k], color="navy")
    xy = np.reshape(roadrunner.evaluate(),(2,1))
    ax_traj.scatter(xy[0], xy[1], color="red")
    # Plot the polygon fill
    ax_traj.fill(polygon_boundaries[k,:,0], polygon_boundaries[k,:,1], "lightblue", alpha=0.5)
    # Plot the line around each polygon
    ax_traj.plot(np.concatenate([polygon_boundaries[k,:,0],polygon_boundaries[k,0:1,0]]),
            np.concatenate([polygon_boundaries[k,:,1],polygon_boundaries[k,0:1,1]]),
            color="navy", alpha=0.5)

    # Plot the plan
    for r in range(30-1):
        # Plot the polygon fill
        #ax_traj.fill(mpcprob.p_plot[r,:,0], mpcprob.p_plot[r,:,1], "lightblue", alpha=0.1)
        # Plot the line around each polygon
        ax_traj.plot(np.concatenate([mpcprob.p_plot[r,:,0],mpcprob.p_plot[r,0:1,0]]),
                np.concatenate([mpcprob.p_plot[r,:,1],mpcprob.p_plot[r,0:1,1]]),
                color="navy", alpha=0.2)
    ax_traj.plot(np.concatenate([mpcprob.p_plot[-1,:,0],mpcprob.p_plot[-1,0:1,0]]),
                np.concatenate([mpcprob.p_plot[-1,:,1],mpcprob.p_plot[-1,0:1,1]]),
                color="red", alpha=0.2)
    
    
    ax_traj.scatter(xk_opt[0], xk_opt[1], color="orange")
    
    fig_traj.canvas.draw()
    # Done!
    
roadrunner.plot(ax=ax_traj)
fig_traj.canvas.draw()
# Out:
# <img src="data:image/png;base64,..." width="1200">
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit http://projects.coin-or.org/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.9635349e+04 1.42e+01 1.03e+01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.9605536e+04 1.42e+01 1.47e+01  -1.0 7.60e+00   2.0 1.26e-02 1.82e-03f  1
#    2  1.9578362e+04 1.42e+01 1.89e+01  -1.0 1.20e+01   1.5 1.69e-03 1.15e-03f  1
#    3  1.9511633e+04 1.41e+01 1.93e+01  -1.0 1.21e+01   1.0 3.03e-03 2.78e-03f  1
#    4  1.9406656e+04 1.41e+01 2.19e+01  -1.0 1.20e+01   1.5 5.93e-03 4.35e-03f  1
#    5  1.9031831e+04 1.38e+01 1.90e+01  -1.0 1.20e+01   1.0 1.03e-02 1.55e-02f  1
#    6  1.8559052e+04 1.35e+01 2.93e+01  -1.0 1.18e+01   1.4 2.57e-02 1.99e-02f  1
#    7  1.8098287e+04 1.32e+01 3.72e+01  -1.0 1.15e+01   0.9 7.07e-03 1.98e-02f  1
#    8  1.6850336e+04 1.25e+01 2.85e+01  -1.0 1.13e+01   0.5 4.05e-02 5.59e-02f  1
#    9  4.8134384e+03 2.95e+00 3.36e+02  -1.0 1.06e+01    -  7.15e-02 7.48e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.3458982e+03 2.42e+00 2.52e+02  -1.0 2.91e+00   0.9 1.09e-02 1.81e-01f  1
#   11  3.9298343e+03 1.90e+00 1.90e+02  -1.0 2.59e+00   1.3 1.26e-01 2.14e-01f  1
#   12  3.9017984e+03 1.88e+00 2.24e+02  -1.0 2.63e+01    -  9.96e-05 1.12e-02f  1
#   13  3.7375474e+03 1.66e+00 2.00e+02  -1.0 2.62e+00   0.8 1.20e-01 1.14e-01f  1
#   14  3.7356318e+03 1.66e+00 2.00e+02  -1.0 6.83e+00   0.4 7.52e-04 1.19e-03f  1
#   15  3.7213041e+03 1.64e+00 1.99e+02  -1.0 1.83e+00   0.8 1.88e-02 1.12e-02f  1
#   16  2.9798855e+03 8.97e-01 1.39e+02  -1.0 3.02e+00    -  2.32e-02 4.53e-01f  1
#   17  2.3490041e+03 1.62e-02 2.26e+02  -1.0 7.69e-01   0.3 7.41e-02 1.00e+00f  1
#   18  2.1820276e+03 1.86e-02 1.86e+02  -1.0 3.38e+00    -  2.14e-01 7.51e-01f  1
#   19  2.1005959e+03 8.02e-02 1.24e+02  -1.0 3.86e+00    -  3.40e-01 4.45e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.0524662e+03 6.37e-02 1.07e+02  -1.0 5.07e+00    -  1.40e-01 2.14e-01f  1
#   21  2.0330702e+03 7.79e-02 1.00e+02  -1.0 9.01e+00    -  6.53e-02 5.53e-02f  1
#   22  2.0177720e+03 7.17e-02 8.33e+01  -1.0 3.48e+00    -  1.73e-01 8.05e-02f  1
#   23  1.9338356e+03 9.86e-02 5.88e+01  -1.0 5.68e+00    -  1.97e-02 2.76e-01f  1
#   24  1.8815134e+03 9.79e-02 4.87e+01  -1.0 1.22e+00  -0.2 1.32e-01 2.14e-01f  1
#   25  1.8147582e+03 7.11e-02 4.12e+01  -1.0 1.07e+00   0.3 1.41e-01 2.79e-01f  1
#   26  1.5668220e+03 2.22e-01 3.02e+01  -1.0 4.85e+00    -  7.76e-02 2.67e-01f  1
#   27  1.4878339e+03 1.94e-01 2.61e+01  -1.0 2.22e+00  -0.2 8.24e-02 1.37e-01f  1
#   28  1.4007447e+03 1.75e-01 2.31e+01  -1.0 5.09e+00  -0.7 1.05e-01 1.16e-01f  1
#   29  1.3517964e+03 1.69e-01 2.22e+01  -1.0 1.51e+01  -1.2 2.75e-02 3.93e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  1.3133320e+03 1.63e-01 2.15e+01  -1.0 1.09e+01    -  6.18e-02 3.43e-02f  1
#   31  1.2482503e+03 1.52e-01 2.01e+01  -1.0 2.82e+00  -0.7 3.86e-02 6.39e-02f  1
#   32  1.2015329e+03 1.48e-01 1.95e+01  -1.0 1.12e+01  -1.2 2.83e-02 2.89e-02f  1
#   33  1.0800773e+03 1.39e-01 1.83e+01  -1.0 1.02e+01    -  3.74e-02 6.35e-02f  1
#   34  9.4252660e+02 1.22e-01 1.61e+01  -1.0 3.42e+00  -0.8 1.09e-01 1.23e-01f  1
#   35  9.4067027e+02 1.22e-01 1.61e+01  -1.0 1.82e+05    -  1.94e-06 1.42e-06f  1
#   36  1.9643270e+02 8.36e-02 5.44e+00  -1.0 4.53e+00    -  9.89e-02 6.63e-01f  1
#   37  9.5154089e+01 7.48e-02 3.08e+00  -1.0 1.93e+00  -1.3 2.48e-01 4.37e-01f  1
#   38  8.6286093e+01 8.42e-02 2.91e+00  -1.0 1.05e+01    -  2.99e-02 5.64e-02f  1
#   39  1.1801336e+01 1.01e-01 1.49e+00  -1.0 2.26e+00    -  3.75e-01 8.59e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  9.9208738e+00 1.55e-01 4.86e-01  -1.0 7.49e-01  -0.8 4.96e-01 1.00e+00f  1
#   41  8.1085827e+00 1.13e-02 2.30e-01  -1.7 2.53e-01  -0.4 6.61e-01 1.00e+00f  1
#   42  6.4279801e+00 1.83e-02 5.43e-02  -1.7 1.56e+00    -  6.98e-01 1.00e+00f  1
#   43  6.0686121e+00 2.13e-03 4.01e-02  -2.5 1.70e+00    -  7.43e-01 1.00e+00h  1
#   44  6.0196259e+00 1.34e-04 9.07e-04  -2.5 1.30e+00    -  1.00e+00 1.00e+00h  1
#   45  6.0035300e+00 4.12e-05 1.12e-03  -3.8 6.45e-01    -  9.31e-01 1.00e+00h  1
#   46  5.9996557e+00 2.22e-06 2.04e-04  -5.7 8.39e-01    -  8.56e-01 1.00e+00h  1
#   47  5.9985407e+00 3.62e-07 2.44e-05  -5.7 8.02e-01    -  8.82e-01 1.00e+00h  1
#   48  5.9981461e+00 1.20e-07 2.62e-05  -5.7 6.81e-01    -  8.95e-01 1.00e+00h  1
#   49  5.9980486e+00 8.53e-08 8.49e-08  -5.7 6.21e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  5.9980217e+00 1.11e-08 6.31e-07  -8.6 4.83e-01    -  8.60e-01 9.99e-01h  1
#   51  5.9980173e+00 7.53e-09 1.50e-06  -8.6 7.83e-01    -  7.93e-01 9.50e-01f  1
#   52  5.9980169e+00 1.51e-09 5.94e-10  -8.6 3.19e-01    -  1.00e+00 1.00e+00f  1
#   53  5.9980169e+00 2.86e-10 8.99e-11  -8.6 1.36e-01    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 53
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.5149731183531485e+00    5.9980168866481955e+00
# Dual infeasibility......:   8.9885326918188047e-11    2.1436957110309808e-10
# Constraint violation....:   2.8629726367412900e-10    2.8629726367412900e-10
# Complementarity.........:   9.9587449305447854e-09    2.3750838459197465e-08
# Overall NLP error.......:   9.9587449305447854e-09    2.3750838459197465e-08
#
#
# Number of objective function evaluations             = 54
# Number of objective gradient evaluations             = 54
# Number of equality constraint evaluations            = 54
# Number of inequality constraint evaluations          = 54
# Number of equality constraint Jacobian evaluations   = 54
# Number of inequality constraint Jacobian evaluations = 54
# Number of Lagrangian Hessian evaluations             = 53
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.229
# Total CPU secs in NLP function evaluations           =      0.180
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   7.45ms (137.87us)   7.46ms (138.19us)        54
#        nlp_g  |  17.43ms (322.76us)  17.51ms (324.30us)        54
#   nlp_grad_f  |  18.15ms (329.93us)  18.13ms (329.71us)        55
#   nlp_hess_l  |  51.94ms (980.04us)  51.93ms (979.83us)        53
#    nlp_jac_g  |  92.41ms (  1.68ms)  92.31ms (  1.68ms)        55
#        total  | 423.04ms (423.04ms) 419.17ms (419.17ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  9.6119456e+00 3.23e+00 2.23e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  7.1474497e+00 2.51e-03 1.03e+00  -1.0 2.35e+00    -  3.78e-01 1.00e+00h  1
#    2  7.1458128e+00 1.37e-05 8.12e-01  -1.0 8.17e-03   2.0 9.94e-01 1.00e+00h  1
#    3  7.1218288e+00 7.94e-07 4.01e-01  -1.7 1.20e-02   1.5 1.00e+00 1.00e+00f  1
#    4  7.0525137e+00 7.44e-06 4.09e-01  -1.7 3.68e-02   1.0 1.00e+00 1.00e+00f  1
#    5  6.8753484e+00 4.90e-05 3.55e-01  -1.7 9.58e-02   0.6 1.00e+00 1.00e+00f  1
#    6  6.5084511e+00 2.12e-04 2.92e-01  -1.7 2.36e-01   0.1 1.00e+00 1.00e+00f  1
#    7  6.3987651e+00 1.64e-05 2.81e-01  -1.7 8.54e-02   0.5 1.00e+00 1.00e+00f  1
#    8  6.1679115e+00 7.55e-05 2.37e-01  -1.7 2.16e-01   0.0 1.00e+00 1.00e+00f  1
#    9  6.1148121e+00 1.41e-02 1.98e-01  -1.7 8.53e-01  -0.4 8.11e-01 4.28e-01f  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  5.7536366e+00 2.00e-04 6.57e-02  -2.5 6.73e-02  -0.0 1.00e+00 1.00e+00f  1
#   11  5.6140738e+00 9.50e-04 8.13e-02  -2.5 2.54e-01  -0.5 1.00e+00 9.56e-01f  1
#   12  5.4770467e+00 6.52e-04 6.56e-02  -2.5 6.06e-01  -1.0 1.00e+00 1.00e+00f  1
#   13  5.2913323e+00 4.31e-02 6.58e-02  -2.5 5.53e+01    -  3.51e-02 1.00e-01f  1
#   14  5.1231171e+00 2.18e-04 5.97e-02  -2.5 1.65e+00  -1.4 1.00e+00 1.00e+00h  1
#   15  5.0918980e+00 3.74e-05 3.43e-03  -2.5 1.44e+00    -  1.00e+00 8.86e-01f  1
#   16  5.0740801e+00 6.26e-06 1.85e-04  -2.5 1.57e+00    -  1.00e+00 1.00e+00f  1
#   17  5.0610506e+00 8.61e-06 1.06e-03  -3.8 6.09e-01    -  9.28e-01 1.00e+00f  1
#   18  5.0575343e+00 9.04e-07 3.91e-04  -5.7 1.12e+00    -  6.75e-01 9.52e-01h  1
#   19  5.0567685e+00 1.86e-07 5.82e-05  -5.7 9.36e-01    -  8.24e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  5.0565384e+00 8.76e-08 3.39e-05  -5.7 9.86e-01    -  8.54e-01 1.00e+00h  1
#   21  5.0564918e+00 2.62e-08 5.64e-08  -5.7 9.04e-01    -  1.00e+00 1.00e+00h  1
#   22  5.0564751e+00 1.60e-08 3.77e-06  -8.6 8.03e-01    -  7.15e-01 5.84e-01h  1
#   23  5.0564624e+00 1.25e-08 4.82e-06  -8.6 9.81e-01    -  7.74e-01 1.00e+00f  1
#   24  5.0564615e+00 2.78e-09 1.15e-06  -8.6 3.80e-01    -  1.00e+00 9.09e-01h  1
#   25  5.0564612e+00 6.43e-10 3.65e-10  -8.6 2.13e-01    -  1.00e+00 1.00e+00f  1
#   26  5.0564612e+00 1.14e-10 6.55e-11  -9.0 8.86e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 26
#
#                                    (scaled)                 (unscaled)
# Objective...............:   5.0564611681000784e+00    5.0564611681000784e+00
# Dual infeasibility......:   6.5539710881802956e-11    6.5539710881802956e-11
# Constraint violation....:   1.1410905553788098e-10    1.1410905553788098e-10
# Complementarity.........:   5.5221881503327758e-09    5.5221881503327758e-09
# Overall NLP error.......:   5.5221881503327758e-09    5.5221881503327758e-09
#
#
# Number of objective function evaluations             = 30
# Number of objective gradient evaluations             = 27
# Number of equality constraint evaluations            = 30
# Number of inequality constraint evaluations          = 30
# Number of equality constraint Jacobian evaluations   = 27
# Number of inequality constraint Jacobian evaluations = 27
# Number of Lagrangian Hessian evaluations             = 26
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.104
# Total CPU secs in NLP function evaluations           =      0.083
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.58ms (119.50us)   3.60ms (119.95us)        30
#        nlp_g  |   8.52ms (284.07us)   8.49ms (282.86us)        30
#   nlp_grad_f  |   8.46ms (302.14us)   8.46ms (302.25us)        28
#   nlp_hess_l  |  24.20ms (930.85us)  24.15ms (928.91us)        26
#    nlp_jac_g  |  42.65ms (  1.52ms)  42.85ms (  1.53ms)        28
#        total  | 196.26ms (196.26ms) 194.35ms (194.35ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.3337065e+01 7.15e-01 4.08e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.5832150e+00 2.17e-03 4.19e-01  -1.0 1.28e+00    -  6.66e-01 1.00e+00f  1
#    2  4.2950669e+00 2.67e-04 1.38e-01  -1.0 3.29e+00    -  7.52e-01 1.00e+00f  1
#    3  4.2412166e+00 1.95e-04 1.84e-01  -1.0 4.95e+00    -  5.99e-01 2.83e-01f  1
#    4  4.2774971e+00 5.63e-05 1.11e-03  -1.0 3.07e+00    -  1.00e+00 1.00e+00f  1
#    5  4.1867191e+00 7.55e-04 2.31e-02  -1.7 7.96e-01    -  1.00e+00 1.00e+00f  1
#    6  4.1284066e+00 3.32e-04 1.02e-02  -2.5 7.36e-01    -  9.59e-01 1.00e+00f  1
#    7  4.1106105e+00 2.85e-05 5.46e-03  -3.8 1.32e+00    -  8.66e-01 1.00e+00h  1
#    8  4.1057318e+00 6.35e-07 9.50e-06  -3.8 1.40e+00    -  1.00e+00 1.00e+00h  1
#    9  4.1038259e+00 2.57e-07 1.22e-04  -5.7 8.92e-01    -  8.32e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.1034206e+00 3.94e-08 1.77e-05  -5.7 4.95e-01    -  8.95e-01 1.00e+00h  1
#   11  4.1033685e+00 1.10e-08 4.30e-08  -5.7 5.88e-01    -  1.00e+00 1.00e+00h  1
#   12  4.1033530e+00 4.77e-09 2.50e-05  -8.6 6.08e-01    -  8.43e-01 9.72e-01h  1
#   13  4.1033511e+00 1.69e-09 5.83e-06  -8.6 4.18e-01    -  9.48e-01 1.00e+00f  1
#   14  4.1033510e+00 2.22e-10 1.11e-06  -8.6 1.21e-01    -  1.00e+00 9.48e-01h  1
#   15  4.1033510e+00 6.89e-12 1.39e-11  -8.6 2.34e-02    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.1033509597175044e+00    4.1033509597175044e+00
# Dual infeasibility......:   1.3862446239476511e-11    1.3862446239476511e-11
# Constraint violation....:   6.8863803548424585e-12    6.8863803548424585e-12
# Complementarity.........:   3.1822796231689002e-09    3.1822796231689002e-09
# Overall NLP error.......:   3.1822796231689002e-09    3.1822796231689002e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.047
# Total CPU secs in NLP function evaluations           =      0.045
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.97ms (123.00us)   1.97ms (123.15us)        16
#        nlp_g  |   4.61ms (288.19us)   4.61ms (287.96us)        16
#   nlp_grad_f  |   4.96ms (291.76us)   4.96ms (291.97us)        17
#   nlp_hess_l  |  13.31ms (887.60us)  13.23ms (882.18us)        15
#    nlp_jac_g  |  24.61ms (  1.45ms)  24.62ms (  1.45ms)        17
#        total  | 102.46ms (102.46ms) 100.71ms (100.71ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  8.0367314e+00 7.33e-01 2.09e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6153155e+00 2.41e-03 2.08e-01  -1.0 1.08e+00    -  8.26e-01 1.00e+00f  1
#    2  3.4800320e+00 4.56e-04 1.34e-01  -1.0 3.24e+00    -  6.69e-01 1.00e+00f  1
#    3  3.4475532e+00 7.76e-05 2.02e-02  -1.0 9.51e-01    -  1.00e+00 1.00e+00f  1
#    4  3.3771722e+00 1.14e-03 4.50e-02  -2.5 2.45e-01    -  9.68e-01 1.00e+00f  1
#    5  3.3528911e+00 2.42e-04 1.85e-03  -2.5 1.44e+00    -  1.00e+00 1.00e+00h  1
#    6  3.3457191e+00 1.97e-05 2.23e-03  -3.8 4.71e-01    -  9.31e-01 1.00e+00h  1
#    7  3.3443281e+00 3.67e-07 4.39e-06  -3.8 1.05e+00    -  1.00e+00 1.00e+00h  1
#    8  3.3436991e+00 1.70e-07 1.53e-04  -5.7 7.53e-01    -  8.34e-01 1.00e+00h  1
#    9  3.3435501e+00 6.66e-08 3.81e-05  -5.7 5.44e-01    -  8.90e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.3435224e+00 3.44e-08 8.53e-08  -5.7 5.89e-01    -  1.00e+00 1.00e+00h  1
#   11  3.3435096e+00 1.60e-08 1.89e-05  -8.6 5.24e-01    -  8.52e-01 9.72e-01h  1
#   12  3.3435073e+00 3.03e-09 8.19e-06  -8.6 4.03e-01    -  9.23e-01 1.00e+00f  1
#   13  3.3435067e+00 6.63e-10 8.22e-10  -8.6 1.63e-01    -  1.00e+00 1.00e+00h  1
#   14  3.3435066e+00 1.37e-10 1.78e-10  -8.6 6.53e-02    -  1.00e+00 1.00e+00h  1
#   15  3.3435065e+00 2.75e-11 3.90e-11  -9.0 2.77e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.3435065405759614e+00    3.3435065405759614e+00
# Dual infeasibility......:   3.9022665273526261e-11    3.9022665273526261e-11
# Constraint violation....:   2.7545410397067371e-11    2.7545410397067371e-11
# Complementarity.........:   6.3338244453750662e-09    6.3338244453750662e-09
# Overall NLP error.......:   6.3338244453750662e-09    6.3338244453750662e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.045
# Total CPU secs in NLP function evaluations           =      0.050
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.24ms (139.75us)   2.23ms (139.29us)        16
#        nlp_g  |   5.30ms (331.25us)   5.30ms (331.28us)        16
#   nlp_grad_f  |   5.07ms (298.12us)   5.07ms (298.31us)        17
#   nlp_hess_l  |  14.19ms (946.27us)  14.02ms (934.57us)        15
#    nlp_jac_g  |  27.02ms (  1.59ms)  27.02ms (  1.59ms)        17
#        total  | 107.13ms (107.13ms) 105.20ms (105.20ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  7.4836154e+00 2.51e+00 2.33e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.2761806e+00 2.38e-03 9.02e-01  -1.0 2.30e+00    -  4.00e-01 1.00e+00h  1
#    2  4.2667043e+00 1.57e-05 8.24e-01  -1.0 8.29e-03   2.0 9.94e-01 1.00e+00h  1
#    3  3.2864931e+00 5.32e-04 3.20e-01  -1.7 1.45e+00    -  5.98e-01 1.00e+00f  1
#    4  3.2835414e+00 1.26e-06 9.18e-01  -1.7 2.75e-02   1.5 1.00e+00 1.00e+00h  1
#    5  3.2762580e+00 1.55e-05 1.93e-01  -1.7 1.74e-02   1.0 1.00e+00 1.00e+00f  1
#    6  3.2540062e+00 1.77e-04 1.11e-01  -2.5 3.00e-02   0.6 1.00e+00 1.00e+00f  1
#    7  3.2118959e+00 4.74e-04 1.12e-01  -2.5 9.08e-02   0.1 1.00e+00 1.00e+00f  1
#    8  3.1658837e+00 2.40e-04 9.65e-02  -2.5 2.34e-01  -0.4 1.00e+00 1.00e+00f  1
#    9  3.0905704e+00 2.18e-03 6.66e-02  -2.5 4.86e-01  -0.9 1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.0450137e+00 1.06e-02 6.24e-02  -2.5 1.81e+01    -  6.13e-02 6.77e-02f  3
#   11  2.9212239e+00 1.77e-03 4.26e-02  -2.5 7.19e-01  -1.3 1.00e+00 1.00e+00h  1
#   12  2.7988794e+00 3.98e-03 3.07e-02  -2.5 5.38e+00    -  3.27e-01 6.23e-01f  1
#   13  2.7741622e+00 2.02e-03 1.25e-02  -2.5 4.75e+00    -  7.30e-01 5.06e-01f  1
#   14  2.7676137e+00 1.26e-03 1.27e-02  -3.8 1.11e+00    -  9.14e-01 3.78e-01h  1
#   15  2.7627515e+00 1.04e-05 2.94e-04  -3.8 1.29e+00    -  1.00e+00 1.00e+00h  1
#   16  2.7616596e+00 2.33e-07 1.11e-04  -5.7 5.57e-01    -  8.86e-01 1.00e+00h  1
#   17  2.7614719e+00 6.73e-08 1.11e-05  -5.7 5.92e-01    -  9.16e-01 1.00e+00h  1
#   18  2.7614316e+00 4.82e-08 9.28e-06  -8.6 6.13e-01    -  8.24e-01 9.94e-01h  1
#   19  2.7614254e+00 1.42e-08 9.10e-07  -8.6 4.51e-01    -  9.02e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  2.7614241e+00 1.37e-09 5.09e-08  -8.6 1.34e-01    -  9.80e-01 1.00e+00h  1
#   21  2.7614239e+00 1.61e-11 2.95e-11  -8.6 1.74e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 21
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.7614239442572526e+00    2.7614239442572526e+00
# Dual infeasibility......:   2.9530970371037012e-11    2.9530970371037012e-11
# Constraint violation....:   1.6088075316389450e-11    1.6088075316389450e-11
# Complementarity.........:   3.8777302326605044e-09    3.8777302326605044e-09
# Overall NLP error.......:   3.8777302326605044e-09    3.8777302326605044e-09
#
#
# Number of objective function evaluations             = 27
# Number of objective gradient evaluations             = 22
# Number of equality constraint evaluations            = 27
# Number of inequality constraint evaluations          = 27
# Number of equality constraint Jacobian evaluations   = 22
# Number of inequality constraint Jacobian evaluations = 22
# Number of Lagrangian Hessian evaluations             = 21
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.089
# Total CPU secs in NLP function evaluations           =      0.073
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   3.48ms (129.00us)   3.50ms (129.61us)        27
#        nlp_g  |   9.10ms (337.19us)   9.08ms (336.37us)        27
#   nlp_grad_f  |   7.31ms (317.78us)   7.26ms (315.78us)        23
#   nlp_hess_l  |  19.59ms (932.90us)  19.56ms (931.64us)        21
#    nlp_jac_g  |  36.63ms (  1.59ms)  36.60ms (  1.59ms)        23
#        total  | 166.70ms (166.70ms) 165.07ms (165.07ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1661988e+01 7.22e-01 3.59e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.5750983e+00 2.20e-03 2.74e-01  -1.0 1.35e+00    -  7.81e-01 1.00e+00f  1
#    2  2.4341782e+00 2.75e-04 2.33e-02  -1.0 2.73e+00    -  9.34e-01 1.00e+00f  1
#    3  2.3308438e+00 5.66e-04 1.14e-01  -1.7 1.82e+00    -  7.54e-01 1.00e+00f  1
#    4  2.2717717e+00 3.32e-04 4.65e-02  -2.5 8.88e-01    -  8.17e-01 1.00e+00f  1
#    5  2.2412973e+00 4.24e-05 3.22e-04  -2.5 1.21e+00    -  1.00e+00 1.00e+00h  1
#    6  2.2254872e+00 9.97e-06 5.04e-03  -3.8 1.45e+00    -  7.68e-01 1.00e+00h  1
#    7  2.2211776e+00 5.83e-07 9.36e-06  -3.8 8.38e-01    -  1.00e+00 1.00e+00h  1
#    8  2.2194800e+00 2.40e-07 2.00e-04  -5.7 1.24e+00    -  8.25e-01 1.00e+00h  1
#    9  2.2191681e+00 5.91e-08 3.39e-05  -5.7 7.44e-01    -  8.55e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.2191141e+00 2.43e-08 7.76e-08  -5.7 7.48e-01    -  1.00e+00 1.00e+00h  1
#   11  2.2190909e+00 1.09e-08 2.32e-05  -8.6 6.14e-01    -  8.15e-01 1.00e+00h  1
#   12  2.2190866e+00 1.13e-08 1.24e-05  -8.6 9.45e-01    -  7.58e-01 1.00e+00h  1
#   13  2.2190861e+00 3.99e-09 5.71e-06  -8.6 3.46e-01    -  9.76e-01 7.15e-01h  1
#   14  2.2190858e+00 5.95e-10 7.27e-10  -8.6 2.14e-01    -  1.00e+00 1.00e+00f  1
#   15  2.2190858e+00 3.84e-11 3.94e-11  -8.6 4.40e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   2.2190858160657796e+00    2.2190858160657796e+00
# Dual infeasibility......:   3.9422615737116743e-11    3.9422615737116743e-11
# Constraint violation....:   3.8433145554961357e-11    3.8433145554961357e-11
# Complementarity.........:   5.1470948615656436e-09    5.1470948615656436e-09
# Overall NLP error.......:   5.1470948615656436e-09    5.1470948615656436e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.050
# Total CPU secs in NLP function evaluations           =      0.049
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.10ms (131.56us)   2.12ms (132.26us)        16
#        nlp_g  |   5.32ms (332.25us)   5.32ms (332.54us)        16
#   nlp_grad_f  |   5.16ms (303.65us)   5.16ms (303.72us)        17
#   nlp_hess_l  |  13.46ms (897.13us)  13.42ms (894.81us)        15
#    nlp_jac_g  |  28.14ms (  1.66ms)  28.13ms (  1.65ms)        17
#        total  | 107.55ms (107.55ms) 106.54ms (106.54ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.6002666e+00 7.40e-01 2.14e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  2.0282900e+00 2.39e-03 2.57e-01  -1.0 1.16e+00    -  7.86e-01 1.00e+00f  1
#    2  1.9645521e+00 3.99e-03 4.48e-01  -1.0 4.32e+00    -  6.72e-01 9.10e-01f  1
#    3  1.8689460e+00 6.73e-04 1.21e-01  -1.0 5.94e+00    -  6.33e-01 1.00e+00f  1
#    4  1.9039592e+00 3.35e-03 1.53e-01  -1.0 5.39e+00    -  6.86e-01 1.00e+00f  1
#    5  1.8144270e+00 7.92e-04 2.35e-02  -1.7 5.63e-01    -  1.00e+00 1.00e+00h  1
#    6  1.7723106e+00 4.59e-04 1.65e-02  -2.5 5.94e-01    -  9.26e-01 1.00e+00h  1
#    7  1.7575794e+00 5.11e-05 3.87e-03  -3.8 9.83e-01    -  9.37e-01 1.00e+00h  1
#    8  1.7549980e+00 1.03e-06 1.73e-05  -3.8 1.08e+00    -  1.00e+00 1.00e+00h  1
#    9  1.7540797e+00 3.40e-07 1.80e-04  -5.7 9.88e-01    -  8.36e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.7537823e+00 2.02e-07 7.13e-05  -5.7 1.12e+00    -  8.24e-01 1.00e+00h  1
#   11  1.7537064e+00 4.72e-08 2.36e-05  -5.7 6.50e-01    -  1.00e+00 9.55e-01h  1
#   12  1.7536899e+00 8.64e-09 3.22e-08  -5.7 3.95e-01    -  1.00e+00 1.00e+00f  1
#   13  1.7536753e+00 4.82e-09 5.96e-06  -8.6 4.63e-01    -  8.63e-01 9.12e-01h  1
#   14  1.7536709e+00 8.28e-09 1.23e-05  -8.6 8.26e-01    -  7.47e-01 1.00e+00f  1
#   15  1.7536704e+00 1.63e-09 1.50e-06  -8.6 2.93e-01    -  1.00e+00 9.12e-01h  1
#   16  1.7536703e+00 2.54e-10 1.64e-10  -8.6 1.35e-01    -  1.00e+00 1.00e+00f  1
#   17  1.7536703e+00 2.49e-11 1.81e-11  -9.0 3.26e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.7536702573507865e+00    1.7536702573507865e+00
# Dual infeasibility......:   1.8123298878249698e-11    1.8123298878249698e-11
# Constraint violation....:   2.4896751327219135e-11    2.4896751327219135e-11
# Complementarity.........:   2.9017993862773986e-09    2.9017993862773986e-09
# Overall NLP error.......:   2.9017993862773986e-09    2.9017993862773986e-09
#
#
# Number of objective function evaluations             = 18
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 18
# Number of inequality constraint evaluations          = 18
# Number of equality constraint Jacobian evaluations   = 18
# Number of inequality constraint Jacobian evaluations = 18
# Number of Lagrangian Hessian evaluations             = 17
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.061
# Total CPU secs in NLP function evaluations           =      0.058
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.12ms (117.61us)   2.12ms (117.96us)        18
#        nlp_g  |   6.26ms (347.89us)   6.26ms (347.89us)        18
#   nlp_grad_f  |   5.81ms (306.05us)   5.82ms (306.13us)        19
#   nlp_hess_l  |  15.14ms (890.53us)  15.03ms (884.35us)        17
#    nlp_jac_g  |  30.20ms (  1.59ms)  30.12ms (  1.59ms)        19
#        total  | 120.06ms (120.06ms) 118.31ms (118.31ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.3201509e+00 3.37e+00 2.17e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.6049834e+00 2.96e-03 8.37e-01  -1.0 2.02e+00    -  4.19e-01 1.00e+00f  1
#    2  1.8785843e+00 3.11e-04 2.57e-01  -1.0 2.19e+00    -  8.76e-01 1.00e+00f  1
#    3  1.5933676e+00 1.25e-04 2.61e-02  -1.0 2.31e+00    -  8.26e-01 1.00e+00f  1
#    4  1.4688926e+00 5.14e-04 3.33e-02  -1.7 1.03e+00    -  9.97e-01 1.00e+00f  1
#    5  1.4284875e+00 3.93e-04 1.20e-02  -2.5 5.83e-01    -  9.86e-01 1.00e+00h  1
#    6  1.4100476e+00 7.05e-05 1.69e-02  -3.8 9.97e-01    -  7.03e-01 1.00e+00h  1
#    7  1.4066849e+00 2.31e-06 1.24e-03  -3.8 1.33e+00    -  9.46e-01 1.00e+00h  1
#    8  1.4054725e+00 9.33e-07 1.61e-05  -3.8 9.22e-01    -  1.00e+00 1.00e+00h  1
#    9  1.4046656e+00 5.73e-07 2.90e-04  -5.7 8.38e-01    -  7.04e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.4044322e+00 1.15e-07 4.42e-05  -5.7 6.90e-01    -  8.84e-01 1.00e+00h  1
#   11  1.4043551e+00 2.09e-08 1.30e-07  -5.7 6.76e-01    -  1.00e+00 1.00e+00h  1
#   12  1.4043280e+00 1.11e-08 2.33e-05  -8.6 6.62e-01    -  8.08e-01 9.87e-01h  1
#   13  1.4043233e+00 8.87e-09 2.24e-05  -8.6 8.69e-01    -  6.93e-01 1.00e+00f  1
#   14  1.4043221e+00 2.72e-09 9.95e-07  -8.6 4.65e-01    -  9.66e-01 9.77e-01h  1
#   15  1.4043219e+00 3.68e-10 2.65e-10  -8.6 1.72e-01    -  1.00e+00 1.00e+00f  1
#   16  1.4043219e+00 8.18e-11 5.50e-07  -9.0 5.02e-02    -  1.00e+00 8.51e-01h  1
#   17  1.4043219e+00 1.02e-11 7.10e-12  -9.0 2.24e-02    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 17
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.4043218839467766e+00    1.4043218839467766e+00
# Dual infeasibility......:   7.0968412317151441e-12    7.0968412317151441e-12
# Constraint violation....:   1.0203393685515039e-11    1.0203393685515039e-11
# Complementarity.........:   1.4151882330789330e-09    1.4151882330789330e-09
# Overall NLP error.......:   1.4151882330789330e-09    1.4151882330789330e-09
#
#
# Number of objective function evaluations             = 18
# Number of objective gradient evaluations             = 18
# Number of equality constraint evaluations            = 18
# Number of inequality constraint evaluations          = 18
# Number of equality constraint Jacobian evaluations   = 18
# Number of inequality constraint Jacobian evaluations = 18
# Number of Lagrangian Hessian evaluations             = 17
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.060
# Total CPU secs in NLP function evaluations           =      0.059
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.49ms (138.56us)   2.49ms (138.15us)        18
#        nlp_g  |   5.52ms (306.72us)   5.52ms (306.84us)        18
#   nlp_grad_f  |   6.15ms (323.79us)   6.16ms (324.22us)        19
#   nlp_hess_l  |  16.02ms (942.29us)  15.87ms (933.47us)        17
#    nlp_jac_g  |  29.83ms (  1.57ms)  29.79ms (  1.57ms)        19
#        total  | 119.99ms (119.99ms) 118.50ms (118.50ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  6.1220323e+00 7.49e-01 2.33e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4337258e+00 2.42e-03 2.30e-01  -1.0 1.21e+00    -  8.08e-01 1.00e+00f  1
#    2  1.9115047e+00 7.99e-02 1.07e+00  -1.0 4.94e+00    -  3.39e-01 5.55e-01f  1
#    3  1.5068662e+00 2.19e-02 1.07e+00  -1.0 6.63e-01    -  2.12e-01 1.00e+00f  1
#    4  1.3115711e+00 1.75e-02 4.35e-01  -1.0 5.94e-01    -  1.00e+00 1.00e+00f  1
#    5  1.1928838e+00 3.13e-03 6.22e-02  -1.7 6.29e-01    -  8.22e-01 1.00e+00h  1
#    6  1.1532026e+00 6.23e-04 1.45e-02  -2.5 3.73e-01    -  9.53e-01 1.00e+00h  1
#    7  1.1381239e+00 9.49e-05 8.50e-03  -3.8 9.69e-01    -  8.87e-01 1.00e+00h  1
#    8  1.1342113e+00 2.44e-06 6.23e-04  -3.8 9.76e-01    -  9.62e-01 1.00e+00h  1
#    9  1.1328731e+00 4.90e-07 2.50e-04  -5.7 8.91e-01    -  8.86e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  1.1324614e+00 1.08e-07 4.00e-05  -5.7 5.57e-01    -  9.00e-01 1.00e+00h  1
#   11  1.1323824e+00 2.40e-08 1.01e-07  -5.7 4.75e-01    -  1.00e+00 1.00e+00h  1
#   12  1.1323563e+00 8.20e-09 1.99e-05  -8.6 4.99e-01    -  8.56e-01 9.43e-01h  1
#   13  1.1323503e+00 6.90e-09 2.99e-05  -8.6 7.45e-01    -  7.44e-01 1.00e+00f  1
#   14  1.1323493e+00 2.20e-09 2.40e-06  -8.6 4.19e-01    -  9.92e-01 9.27e-01h  1
#   15  1.1323491e+00 4.56e-10 4.12e-06  -8.6 1.36e-01    -  1.00e+00 8.75e-01f  1
#   16  1.1323490e+00 3.79e-11 9.71e-11  -8.6 4.20e-02    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 16
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.1323490248207073e+00    1.1323490248207073e+00
# Dual infeasibility......:   9.7125492839219206e-11    9.7125492839219206e-11
# Constraint violation....:   3.7915337536276184e-11    3.7915337536276184e-11
# Complementarity.........:   5.7978213443790788e-09    5.7978213443790788e-09
# Overall NLP error.......:   5.7978213443790788e-09    5.7978213443790788e-09
#
#
# Number of objective function evaluations             = 17
# Number of objective gradient evaluations             = 17
# Number of equality constraint evaluations            = 17
# Number of inequality constraint evaluations          = 17
# Number of equality constraint Jacobian evaluations   = 17
# Number of inequality constraint Jacobian evaluations = 17
# Number of Lagrangian Hessian evaluations             = 16
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.053
# Total CPU secs in NLP function evaluations           =      0.048
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.11ms (124.00us)   2.11ms (124.41us)        17
#        nlp_g  |   4.90ms (288.41us)   4.90ms (288.33us)        17
#   nlp_grad_f  |   5.23ms (290.50us)   5.23ms (290.78us)        18
#   nlp_hess_l  |  14.20ms (887.50us)  14.09ms (880.36us)        16
#    nlp_jac_g  |  27.35ms (  1.52ms)  27.35ms (  1.52ms)        18
#        total  | 110.34ms (110.34ms) 108.76ms (108.76ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0768231e+01 2.65e+00 2.81e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.4545460e+00 2.38e-03 1.29e+00  -1.0 1.57e+00    -  4.68e-01 1.00e+00f  1
#    2  1.2240433e+00 1.28e-04 3.38e-01  -1.0 3.52e-01   0.0 9.87e-01 1.00e+00f  1
#    3  1.0065233e+00 1.13e-03 1.28e-02  -1.7 2.68e-01    -  9.95e-01 1.00e+00f  1
#    4  9.7977478e-01 5.76e-04 1.49e-02  -3.8 4.57e-01    -  9.13e-01 1.00e+00h  1
#    5  9.7156006e-01 6.13e-05 6.53e-04  -3.8 8.07e-01    -  9.42e-01 9.21e-01h  1
#    6  9.7015515e-01 5.72e-06 9.04e-05  -5.7 6.52e-01    -  9.02e-01 9.05e-01h  1
#    7  9.6979605e-01 9.93e-08 2.89e-04  -5.7 1.12e+00    -  7.67e-01 1.00e+00h  1
#    8  9.6971461e-01 1.67e-08 1.77e-05  -5.7 6.21e-01    -  9.57e-01 1.00e+00h  1
#    9  9.6968622e-01 3.41e-09 7.24e-06  -8.6 3.13e-01    -  9.23e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  9.6968355e-01 5.70e-09 8.43e-06  -8.6 6.71e-01    -  7.81e-01 1.00e+00h  1
#   11  9.6968293e-01 1.79e-09 6.60e-07  -8.6 3.63e-01    -  1.00e+00 9.21e-01h  1
#   12  9.6968278e-01 3.09e-10 1.04e-10  -8.6 1.59e-01    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   9.6968277817975879e-01    9.6968277817975879e-01
# Dual infeasibility......:   1.0410620098128740e-10    1.0410620098128740e-10
# Constraint violation....:   3.0919861115918934e-10    3.0919861115918934e-10
# Complementarity.........:   8.3308352560895844e-09    8.3308352560895844e-09
# Overall NLP error.......:   8.3308352560895844e-09    8.3308352560895844e-09
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 13
# Number of inequality constraint evaluations          = 13
# Number of equality constraint Jacobian evaluations   = 13
# Number of inequality constraint Jacobian evaluations = 13
# Number of Lagrangian Hessian evaluations             = 12
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.048
# Total CPU secs in NLP function evaluations           =      0.039
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.82ms (140.08us)   1.83ms (140.50us)        13
#        nlp_g  |   4.04ms (310.77us)   4.04ms (310.97us)        13
#   nlp_grad_f  |   4.21ms (300.79us)   4.21ms (300.93us)        14
#   nlp_hess_l  |  10.19ms (848.83us)  10.13ms (843.89us)        12
#    nlp_jac_g  |  20.08ms (  1.43ms)  20.07ms (  1.43ms)        14
#        total  |  89.07ms ( 89.07ms)  87.92ms ( 87.92ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  5.8712245e+00 8.00e-01 2.05e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0730508e+00 3.29e-03 2.92e-01  -1.0 1.28e+00    -  7.57e-01 1.00e+00f  1
#    2  9.3335645e-01 8.90e-05 5.18e-01  -1.0 5.19e-01   0.0 9.99e-01 1.00e+00f  1
#    3  8.1197521e-01 1.08e-03 1.46e-02  -1.7 1.98e-01    -  9.79e-01 1.00e+00f  1
#    4  7.8384836e-01 6.98e-04 2.67e-02  -2.5 6.31e-01    -  7.44e-01 1.00e+00h  1
#    5  7.7395240e-01 5.76e-05 2.43e-02  -3.8 8.13e-01    -  6.32e-01 1.00e+00h  1
#    6  7.7259541e-01 1.87e-06 1.82e-04  -3.8 8.56e-01    -  9.95e-01 1.00e+00h  1
#    7  7.7169356e-01 8.37e-07 7.27e-04  -5.7 1.33e+00    -  7.31e-01 1.00e+00h  1
#    8  7.7142585e-01 1.58e-07 1.65e-04  -5.7 9.45e-01    -  7.37e-01 1.00e+00h  1
#    9  7.7137797e-01 1.86e-08 8.23e-06  -5.7 8.09e-01    -  9.27e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  7.7136097e-01 3.83e-09 2.87e-06  -8.6 3.30e-01    -  9.11e-01 9.59e-01h  1
#   11  7.7135864e-01 2.52e-09 2.30e-06  -8.6 4.27e-01    -  8.72e-01 1.00e+00f  1
#   12  7.7135821e-01 1.22e-09 5.11e-10  -8.6 3.29e-01    -  1.00e+00 1.00e+00h  1
#   13  7.7135815e-01 1.02e-10 9.23e-09  -8.6 7.11e-02    -  1.00e+00 9.75e-01h  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.7135815152747944e-01    7.7135815152747944e-01
# Dual infeasibility......:   9.2256039677215254e-09    9.2256039677215254e-09
# Constraint violation....:   1.0245349013615623e-10    1.0245349013615623e-10
# Complementarity.........:   9.2331594194687051e-09    9.2331594194687051e-09
# Overall NLP error.......:   9.2331594194687051e-09    9.2331594194687051e-09
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 14
# Number of inequality constraint evaluations          = 14
# Number of equality constraint Jacobian evaluations   = 14
# Number of inequality constraint Jacobian evaluations = 14
# Number of Lagrangian Hessian evaluations             = 13
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.052
# Total CPU secs in NLP function evaluations           =      0.045
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.80ms (128.29us)   1.80ms (128.42us)        14
#        nlp_g  |   4.94ms (352.93us)   4.94ms (353.07us)        14
#   nlp_grad_f  |   4.83ms (321.80us)   4.79ms (319.24us)        15
# ...
#        nlp_f  |   2.21ms (147.60us)   2.18ms (145.34us)        15
#        nlp_g  |   5.03ms (335.33us)   5.03ms (335.55us)        15
#   nlp_grad_f  |   5.19ms (324.44us)   5.20ms (324.76us)        16
#   nlp_hess_l  |  12.88ms (920.07us)  12.72ms (908.29us)        14
#    nlp_jac_g  |  25.06ms (  1.57ms)  25.06ms (  1.57ms)        16
#        total  | 100.34ms (100.34ms)  98.90ms ( 98.90ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.1027479e+01 2.21e+00 3.16e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.5621147e+00 5.85e-02 1.45e+00  -1.0 1.01e+00    -  5.64e-01 9.92e-01f  1
#    2  5.1040089e+00 2.82e-03 1.43e-01  -1.0 6.01e-01    -  8.08e-01 1.00e+00f  1
#    3  5.0454359e+00 5.49e-04 1.58e-01  -1.0 2.30e+00    -  8.10e-01 1.00e+00f  1
#    4  4.8968301e+00 8.84e-04 5.40e-02  -1.7 2.12e+00    -  9.25e-01 1.00e+00f  1
#    5  4.7859995e+00 7.29e-04 1.44e-02  -2.5 1.09e+00    -  9.48e-01 1.00e+00f  1
#    6  4.7362757e+00 2.35e-04 1.54e-02  -3.8 8.17e-01    -  7.66e-01 9.59e-01h  1
#    7  4.7228194e+00 2.40e-05 2.11e-03  -3.8 8.94e-01    -  8.93e-01 1.00e+00h  1
#    8  4.7180388e+00 1.69e-06 1.84e-05  -3.8 2.22e+00    -  1.00e+00 1.00e+00h  1
#    9  4.7155761e+00 5.95e-07 7.13e-04  -5.7 1.14e+00    -  8.27e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.7153055e+00 1.19e-07 3.30e-04  -5.7 8.14e-01    -  8.51e-01 9.60e-01h  1
#   11  4.7152796e+00 2.11e-08 3.48e-08  -5.7 5.95e-01    -  1.00e+00 1.00e+00f  1
#   12  4.7152529e+00 2.29e-09 8.23e-07  -8.6 3.12e-01    -  9.14e-01 9.04e-01h  1
#   13  4.7152503e+00 5.10e-10 7.30e-10  -8.6 1.41e-01    -  1.00e+00 1.00e+00f  1
#   14  4.7152503e+00 1.76e-12 2.39e-12  -8.6 8.30e-03    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 14
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.7152502623921260e+00    4.7152502623921260e+00
# Dual infeasibility......:   2.3867311356796288e-12    2.3867311356796288e-12
# Constraint violation....:   1.7612022951141171e-12    1.7612022951141171e-12
# Complementarity.........:   2.6146494807704199e-09    2.6146494807704199e-09
# Overall NLP error.......:   2.6146494807704199e-09    2.6146494807704199e-09
#
#
# Number of objective function evaluations             = 15
# Number of objective gradient evaluations             = 15
# Number of equality constraint evaluations            = 15
# Number of inequality constraint evaluations          = 15
# Number of equality constraint Jacobian evaluations   = 15
# Number of inequality constraint Jacobian evaluations = 15
# Number of Lagrangian Hessian evaluations             = 14
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.056
# Total CPU secs in NLP function evaluations           =      0.056
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.16ms (143.80us)   2.16ms (143.97us)        15
#        nlp_g  |   6.12ms (408.27us)   6.13ms (408.85us)        15
#   nlp_grad_f  |   5.34ms (333.94us)   5.30ms (331.28us)        16
#   nlp_hess_l  |  14.61ms (  1.04ms)  14.57ms (  1.04ms)        14
#    nlp_jac_g  |  28.74ms (  1.80ms)  28.69ms (  1.79ms)        16
#        total  | 112.84ms (112.84ms) 111.39ms (111.39ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0616338e+01 2.20e+00 3.14e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.2283268e+00 5.52e-02 1.39e+00  -1.0 1.03e+00    -  5.64e-01 9.98e-01f  1
#    2  4.7659878e+00 2.79e-03 1.20e-01  -1.0 6.38e-01    -  8.32e-01 1.00e+00f  1
#    3  4.7198933e+00 5.00e-04 1.67e-01  -1.0 2.39e+00    -  7.66e-01 1.00e+00f  1
#    4  4.5515524e+00 8.98e-04 4.39e-02  -1.7 1.30e+00    -  9.63e-01 1.00e+00f  1
#    5  4.4239760e+00 7.11e-04 2.14e-02  -2.5 1.38e+00    -  9.03e-01 1.00e+00f  1
#    6  4.3744520e+00 1.74e-04 1.73e-02  -3.8 9.25e-01    -  7.68e-01 1.00e+00h  1
#    7  4.3611926e+00 1.72e-05 2.72e-03  -3.8 8.81e-01    -  8.68e-01 1.00e+00h  1
#    8  4.3560897e+00 1.90e-06 2.40e-05  -3.8 1.54e+00    -  1.00e+00 1.00e+00h  1
#    9  4.3534805e+00 6.49e-07 7.41e-04  -5.7 1.05e+00    -  8.33e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.3531426e+00 1.25e-07 3.48e-04  -5.7 1.39e+00    -  8.54e-01 9.64e-01h  1
#   11  4.3531107e+00 1.79e-08 3.75e-08  -5.7 5.55e-01    -  1.00e+00 1.00e+00f  1
#   12  4.3530828e+00 5.82e-09 4.05e-06  -8.6 3.13e-01    -  9.31e-01 8.94e-01h  1
#   13  4.3530793e+00 1.43e-09 1.15e-09  -8.6 1.57e-01    -  1.00e+00 1.00e+00f  1
#   14  4.3530791e+00 2.33e-10 1.83e-10  -8.6 6.33e-02    -  1.00e+00 1.00e+00h  1
#   15  4.3530790e+00 2.23e-11 1.79e-11  -8.6 1.97e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.3530790418940102e+00    4.3530790418940102e+00
# Dual infeasibility......:   1.7909548566678551e-11    1.7909548566678551e-11
# Constraint violation....:   2.2341017924532025e-11    2.2341017924532025e-11
# Complementarity.........:   7.8030849177235302e-09    7.8030849177235302e-09
# Overall NLP error.......:   7.8030849177235302e-09    7.8030849177235302e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.056
# Total CPU secs in NLP function evaluations           =      0.054
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.17ms (135.56us)   2.17ms (135.80us)        16
#        nlp_g  |   5.66ms (353.94us)   5.67ms (354.08us)        16
#   nlp_grad_f  |   5.79ms (340.76us)   5.75ms (338.08us)        17
#   nlp_hess_l  |  14.07ms (937.93us)  13.95ms (930.04us)        15
#    nlp_jac_g  |  27.84ms (  1.64ms)  27.82ms (  1.64ms)        17
#        total  | 110.61ms (110.61ms) 109.53ms (109.53ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0420255e+01 2.19e+00 3.08e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.8573966e+00 5.82e-02 1.47e+00  -1.0 9.95e-01    -  5.67e-01 1.00e+00f  1
#    2  4.4220967e+00 2.70e-03 1.31e-01  -1.0 6.21e-01    -  8.38e-01 1.00e+00f  1
#    3  4.3881253e+00 4.66e-04 1.85e-01  -1.0 2.47e+00    -  7.26e-01 1.00e+00f  1
#    4  4.2053371e+00 8.77e-04 4.86e-02  -1.7 1.02e+00    -  9.55e-01 1.00e+00f  1
#    5  4.0844293e+00 6.41e-04 2.10e-02  -2.5 1.27e+00    -  9.01e-01 1.00e+00f  1
#    6  4.0353770e+00 1.50e-04 1.75e-02  -3.8 9.61e-01    -  7.61e-01 1.00e+00h  1
#    7  4.0211042e+00 1.86e-05 3.10e-03  -3.8 8.55e-01    -  8.46e-01 1.00e+00h  1
#    8  4.0157900e+00 2.09e-06 2.72e-05  -3.8 1.42e+00    -  1.00e+00 1.00e+00h  1
#    9  4.0130463e+00 6.68e-07 6.95e-04  -5.7 1.06e+00    -  8.43e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.0127168e+00 1.31e-07 3.91e-04  -5.7 8.81e-01    -  8.50e-01 9.88e-01h  1
#   11  4.0126934e+00 1.35e-08 3.51e-08  -5.7 4.99e-01    -  1.00e+00 1.00e+00f  1
#   12  4.0126669e+00 4.04e-09 3.28e-06  -8.6 3.74e-01    -  8.12e-01 8.87e-01h  1
#   13  4.0126634e+00 1.40e-09 1.69e-07  -8.6 2.20e-01    -  9.87e-01 1.00e+00f  1
#   14  4.0126633e+00 3.44e-10 3.28e-10  -8.6 1.08e-01    -  1.00e+00 1.00e+00h  1
#   15  4.0126633e+00 8.36e-11 8.01e-11  -8.6 5.35e-02    -  1.00e+00 1.00e+00h  1
#   16  4.0126633e+00 2.12e-11 2.05e-11  -9.0 2.70e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 16
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.0126632510505091e+00    4.0126632510505091e+00
# Dual infeasibility......:   2.0456438273558036e-11    2.0456438273558036e-11
# Constraint violation....:   2.1227630764286687e-11    2.1227630764286687e-11
# Complementarity.........:   5.7906005947508719e-09    5.7906005947508719e-09
# Overall NLP error.......:   5.7906005947508719e-09    5.7906005947508719e-09
#
#
# Number of objective function evaluations             = 17
# Number of objective gradient evaluations             = 17
# Number of equality constraint evaluations            = 17
# Number of inequality constraint evaluations          = 17
# Number of equality constraint Jacobian evaluations   = 17
# Number of inequality constraint Jacobian evaluations = 17
# Number of Lagrangian Hessian evaluations             = 16
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.059
# Total CPU secs in NLP function evaluations           =      0.059
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.17ms (127.41us)   2.17ms (127.61us)        17
#        nlp_g  |   6.01ms (353.53us)   6.02ms (354.36us)        17
#   nlp_grad_f  |   5.58ms (309.94us)   5.54ms (307.71us)        18
#   nlp_hess_l  |  16.68ms (  1.04ms)  16.54ms (  1.03ms)        16
#    nlp_jac_g  |  29.41ms (  1.63ms)  29.34ms (  1.63ms)        18
#        total  | 118.06ms (118.06ms) 116.38ms (116.38ms)         1
# This is Ipopt version 3.12.3, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:     2834
# Number of nonzeros in inequality constraint Jacobian.:      960
# Number of nonzeros in Lagrangian Hessian.............:      480
#
# Total number of variables............................:      540
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:      300
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      480
# Total number of inequality constraints...............:      480
#         inequality constraints with only lower bounds:      240
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:      240
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.0239595e+01 2.17e+00 2.91e-01  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.5363697e+00 5.67e-02 1.48e+00  -1.0 1.00e+00    -  5.68e-01 1.00e+00f  1
#    2  4.1193830e+00 2.46e-03 1.23e-01  -1.0 6.31e-01    -  8.48e-01 1.00e+00f  1
#    3  4.0779390e+00 4.35e-04 1.95e-01  -1.0 2.57e+00    -  6.93e-01 1.00e+00f  1
#    4  3.8813369e+00 8.24e-04 4.07e-02  -1.7 1.26e+00    -  9.81e-01 1.00e+00f  1
#    5  3.7675394e+00 5.91e-04 9.82e-03  -2.5 1.35e+00    -  9.48e-01 1.00e+00f  1
#    6  3.7195225e+00 1.35e-04 9.16e-03  -3.8 1.10e+00    -  8.48e-01 1.00e+00h  1
#    7  3.7045664e+00 1.94e-05 9.92e-04  -3.8 1.33e+00    -  9.16e-01 1.00e+00h  1
#    8  3.6990243e+00 2.53e-06 1.75e-03  -5.7 1.48e+00    -  8.07e-01 1.00e+00h  1
#    9  3.6981123e+00 2.18e-07 1.12e-03  -5.7 1.09e+00    -  7.96e-01 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  3.6980213e+00 3.52e-08 8.67e-05  -5.7 5.20e-01    -  9.27e-01 9.32e-01h  1
#   11  3.6980128e+00 1.17e-08 1.13e-08  -5.7 6.95e-01    -  1.00e+00 1.00e+00f  1
#   12  3.6979852e+00 2.21e-09 5.44e-06  -8.6 2.94e-01    -  8.61e-01 9.57e-01h  1
#   13  3.6979838e+00 1.40e-09 2.57e-07  -8.6 2.59e-01    -  9.76e-01 1.00e+00f  1
#   14  3.6979837e+00 2.77e-10 2.51e-10  -8.6 1.17e-01    -  1.00e+00 1.00e+00h  1
#   15  3.6979837e+00 3.04e-11 2.76e-11  -8.6 3.84e-02    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 15
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.6979837077514621e+00    3.6979837077514621e+00
# Dual infeasibility......:   2.7585854378608014e-11    2.7585854378608014e-11
# Constraint violation....:   3.0442648402129180e-11    3.0442648402129180e-11
# Complementarity.........:   6.3719807544554814e-09    6.3719807544554814e-09
# Overall NLP error.......:   6.3719807544554814e-09    6.3719807544554814e-09
#
#
# Number of objective function evaluations             = 16
# Number of objective gradient evaluations             = 16
# Number of equality constraint evaluations            = 16
# Number of inequality constraint evaluations          = 16
# Number of equality constraint Jacobian evaluations   = 16
# Number of inequality constraint Jacobian evaluations = 16
# Number of Lagrangian Hessian evaluations             = 15
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.053
# Total CPU secs in NLP function evaluations           =      0.053
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   2.01ms (125.31us)   2.01ms (125.58us)        16
#        nlp_g  |   5.17ms (322.94us)   5.27ms (329.23us)        16
#   nlp_grad_f  |   5.42ms (318.88us)   5.47ms (321.76us)        17
#   nlp_hess_l  |  13.75ms (917.00us)  13.67ms (911.02us)        15
#    nlp_jac_g  |  27.78ms (  1.63ms)  27.90ms (  1.64ms)        17
#        total  | 106.72ms (106.72ms) 105.60ms (105.60ms)         1

# %%
# turn interactive off
plt.ioff()
# FOR PLOTTING: We also want to include the polygons for the lookahead steps k=1,...,N.
polygon_boundaries[n_runs-1:n_runs+mpcprob.model.N+2,:,:] = mpcprob.p_plot

# %% [markdown]
# ## Control signals: acceleration and steering angle

# %%
u_plt, u_ax1, u_ax2 = car.plot_u(u_plan, mpcprob.u_opt)
plt.show()

# %% [markdown]
# ## x-y plot of car's path
# Arrows show velocity. Orange components are planned but not executed.

# %%
x_plt, x_ax = car.plot_x(x_plan, mpcprob.x_opt)
    
roadrunner.plot(ax=x_ax)
x_ax.scatter(ic[0], ic[1], color="green")
plt.show()

# %% [markdown]
# ## x vs time and y vs time, separately, with the boundaries

# %%
# Plot the road boundary as polygons
def plot_polygons(polygon_boundaries, ax=None):
    n_polys,_,_ = np.shape(polygon_boundaries)
    
    if ax is None:
        fig, ax = plt.subplots(1,1,figsize=(12,4))
        
    for k in range(n_polys):
        # Plot the polygon fill
        ax.fill(polygon_boundaries[k,:,0], polygon_boundaries[k,:,1], "lightblue", alpha=0.1+(k/(n_polys)/2))
        # Plot the line around each polygon
        ax.plot(np.concatenate([polygon_boundaries[k,:,0],polygon_boundaries[k,0:1,0]]),
                np.concatenate([polygon_boundaries[k,:,1],polygon_boundaries[k,0:1,1]]),
                color="navy", alpha=0.1+k/(n_polys)/2)

    # Plot the last polygon in RED
    ax.plot(np.concatenate([polygon_boundaries[-1,:,0],polygon_boundaries[-1,0:1,0]]),
            np.concatenate([polygon_boundaries[-1,:,1],polygon_boundaries[-1,0:1,1]]),
            color="red", alpha=1)
    return ax

ax = plot_polygons(polygon_boundaries)
ax.scatter(test_road[0:15,0], test_road[0:15,1], color='red')
ax.scatter(ic[0], ic[1], color="green")
plt.title("Polygon boundaries along road")
roadrunner.plot(ax=ax)
plt.show()
